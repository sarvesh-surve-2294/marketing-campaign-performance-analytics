# %% [markdown]
# # 📊 Marketing Campaign Performance Analytics
#
# ## Data Understanding
#
# ### Project Overview
# This notebook focuses on understanding the marketing campaign dataset before any preprocessing or analysis. The objective is to explore the dataset's structure, identify data types, inspect missing values, detect duplicates, and gain initial insights that will guide the data cleaning and feature engineering stages.
#
# ### Objectives
# - Load the dataset into Python
# - Understand the dataset structure
# - Examine columns and data types
# - Identify missing values and duplicates
# - Generate descriptive statistics
# - Explore categorical and numerical features
# - Document key observations

# %%
# Import required libraries

import pandas as pd
import numpy as np

# Display all columns
pd.set_option('display.max_columns', None)

# Display numbers with two decimal places
pd.set_option('display.float_format', '{:.2f}'.format)

# %%
# Load dataset

df = pd.read_csv("../data/raw/digital_marketing_dataset_30k.csv")

# Display dataset
df.head()
# Out:
#          date  year  month month_name  week day_of_week  post_hour  season  \
# 0  08/04/2023  2023      4        Apr    14         Sat          7  Spring
# 1  28/04/2025  2025      4        Apr    18         Mon         12  Spring
# 2  18/12/2024  2024     12        Dec    51         Wed         10  Winter
# 3  26/04/2024  2024      4        Apr    17         Fri         20  Spring
# 4  19/04/2024  2024      4        Apr    16         Fri         22  Spring
#
#    is_holiday is_holiday (text)  is_weekend is_weekend (text)  \
# 0           0                No           1               Yes
# 1           0                No           0                No
# 2           0                No           0                No
# 3           0                No           0                No
# 4           0                No           0                No
#
#                 country market_tier          account account_type  \
# 0                  Iraq      Tier 1   Travel_SkyTrip        Brand
# ...

# %%
# Last five records

df.tail()
# Out:
#              date  year  month month_name  week day_of_week  post_hour  \
# 29995  05/05/2023  2023      5        May    18         Fri          7
# 29996  12/10/2025  2025     10        Oct    41         Sun          0
# 29997  29/11/2023  2023     11        Nov    48         Wed         13
# 29998  23/03/2025  2025      3        Mar    12         Sun          4
# 29999  28/07/2025  2025      7        Jul    31         Mon         10
#
#        season  is_holiday is_holiday (text)  is_weekend is_weekend (text)  \
# 29995  Spring           0                No           0                No
# 29996    Fall           0                No           1               Yes
# 29997    Fall           0                No           0                No
# 29998  Spring           0                No           1               Yes
# 29999  Summer           0                No           0                No
#
#       country market_tier          account account_type        platform  \
# ...

# %%
# Shape of dataset

print(f"Rows    : {df.shape[0]}")
print(f"Columns : {df.shape[1]}")
# Out:
# Rows    : 30000
# Columns : 35

# %%
# Column names

df.columns
# Out:
# Index(['date', 'year', 'month', 'month_name', 'week', 'day_of_week',
#        'post_hour', 'season', 'is_holiday', 'is_holiday (text)', 'is_weekend',
#        'is_weekend (text)', 'country', 'market_tier', 'account',
#        'account_type', 'platform', 'placement', 'funnel_stage', 'objective',
#        'theme', 'campaign_id', 'campaign_name', 'ad_group_id', 'ad_group_name',
#        'ad_id', 'ad_name', 'spend', 'impressions', 'reach', 'frequency',
#        'clicks', 'conversions', 'revenue', 'video_views'],
#       dtype='object')

# %%
# Dataset information

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 35 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   date               30000 non-null  object
#  1   year               30000 non-null  int64
#  2   month              30000 non-null  int64
#  3   month_name         30000 non-null  object
#  4   week               30000 non-null  int64
#  5   day_of_week        30000 non-null  object
#  6   post_hour          30000 non-null  int64
#  7   season             30000 non-null  object
#  8   is_holiday         30000 non-null  int64
#  9   is_holiday (text)  30000 non-null  object
#  10  is_weekend         30000 non-null  int64
#  11  is_weekend (text)  30000 non-null  object
#  12  country            30000 non-null  object
#  13  market_tier        30000 non-null  object
#  14  account            30000 non-null  object
#  15  account_type       30000 non-null  object
# ...

# %%
# Summary statistics

df.describe()
# Out:
#           year    month     week  post_hour  is_holiday  is_weekend    spend  \
# count 30000.00 30000.00 30000.00   30000.00    30000.00    30000.00 30000.00
# mean   2024.00     6.53    26.46      11.50        0.02        0.28   421.21
# std       0.82     3.45    15.09       6.92        0.12        0.45   463.30
# min    2023.00     1.00     1.00       0.00        0.00        0.00    18.84
# 25%    2023.00     4.00    13.00       5.00        0.00        0.00    86.15
# 50%    2024.00     7.00    27.00      11.00        0.00        0.00   229.91
# 75%    2025.00    10.00    40.00      18.00        0.00        1.00   609.31
# max    2025.00    12.00    52.00      23.00        1.00        1.00  3759.94
#
#        impressions     reach  frequency   clicks  conversions   revenue  \
# count     30000.00  30000.00   30000.00 30000.00     30000.00  30000.00
# mean      56725.45  28648.65       2.07   853.90        10.76    475.71
# ...

# %%
# Summary statistics including categorical columns

df.describe(include='all')
# Out:
#               date     year    month month_name     week day_of_week  \
# count        30000 30000.00 30000.00      30000 30000.00       30000
# unique        1096      NaN      NaN         12      NaN           7
# top     27/04/2025      NaN      NaN        Jul      NaN         Mon
# freq            45      NaN      NaN       2618      NaN        4363
# mean           NaN  2024.00     6.53        NaN    26.46         NaN
# std            NaN     0.82     3.45        NaN    15.09         NaN
# min            NaN  2023.00     1.00        NaN     1.00         NaN
# 25%            NaN  2023.00     4.00        NaN    13.00         NaN
# 50%            NaN  2024.00     7.00        NaN    27.00         NaN
# 75%            NaN  2025.00    10.00        NaN    40.00         NaN
# max            NaN  2025.00    12.00        NaN    52.00         NaN
#
#         post_hour  season  is_holiday is_holiday (text)  is_weekend  \
# count    30000.00   30000    30000.00             30000    30000.00
# ...

# %%
# Missing values

missing_values = df.isnull().sum()

missing_values[missing_values > 0].sort_values(ascending=False)
# Out:
# Series([], dtype: int64)

# %%
# Duplicate records

print(f"Duplicate Records: {df.duplicated().sum()}")
# Out:
# Duplicate Records: 0

# %%
# Unique values in each column

df.nunique().sort_values()
# Out:
# is_weekend (text)        2
# is_holiday               2
# is_holiday (text)        2
# is_weekend               2
# account_type             2
# year                     3
# funnel_stage             3
# market_tier              3
# season                   4
# objective                6
# platform                 6
# day_of_week              7
# account                  7
# theme                    8
# placement               11
# month_name              12
# month                   12
# country                 12
# post_hour               24
# week                    52
# ad_name                 99
# frequency              210
# conversions            405
# date                  1096
# ad_group_name         4041
# clicks                4279
# video_views           8607
# revenue               8744
# campaign_name        19192
# reach                21739
# spend                24027
# impressions          25004
# campaign_id          25548
# ad_group_id          29496
# ...

# %% [markdown]
# # Initial Observations
#
# - Dataset contains marketing campaign performance data collected from multiple advertising platforms.
# - The dataset consists of both numerical and categorical variables.
# - Date-related features enable time-series analysis.
# - Campaign hierarchy includes Campaign, Ad Group, and Ad level information.
# - Performance metrics include spend, impressions, clicks, conversions, revenue, reach, and video views.
# - Marketing KPIs such as CTR, CPC, CPM, CPA, ROAS, ROI, and Conversion Rate are not directly available and will be derived during feature engineering.
# - Data quality observations (missing values, duplicates, data types) will be addressed in the next notebook.

# %% [markdown]
# ## Key Findings
#
# - The dataset contains **30,000 records** and **35 features**, providing sufficient data for comprehensive marketing campaign analysis.
#
# - There are **no missing values** and **no duplicate records**, indicating high-quality data that requires minimal preprocessing.
#
# - The dataset includes **21 categorical columns**, **11 integer columns**, **1 floating-point column**, and **2 boolean indicator columns represented as text**, offering a balanced mix of numerical and categorical features.
#
# - Campaign data spans **2023 to 2025**, enabling trend and seasonality analysis.
#
# - The dataset captures the complete marketing campaign hierarchy:
#   - Campaign
#   - Ad Group
#   - Advertisement
#
# - Performance metrics include:
#   - Spend
#   - Impressions
#   - Reach
#   - Frequency
#   - Clicks
#   - Conversions
#   - Revenue
#   - Video Views
#
# - Marketing KPIs such as CTR, CPC, CPM, CPA, Conversion Rate, ROAS, and ROI are not directly available and will be engineered during the feature engineering stage.
#
# - The dataset covers multiple advertising platforms including Meta, Google Search, Google Display, TikTok, LinkedIn, and Snapchat, making it suitable for cross-platform campaign analysis.
#
# - Since the dataset is already clean, the next notebook will focus primarily on validating data types, removing redundant columns, and preparing the dataset for feature engineering.
